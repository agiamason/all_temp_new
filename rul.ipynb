# %% [markdown]
# Due to the RUL baseline containing 16 models, with each model running 16 different seeds, and 2 out of these 16 models being Neural Network models, it is not feasible to reproduce our RUL baseline tasks on Code Ocean because it only provides 10 hours of CPU time per month. Therefore, we are presenting the results obtained from running the tasks on a V100 machine.

# %% [markdown]
# You can refer to the rul_baseline.ipynb documents saved in /code/src/ to check the specific baseline details.

# %% [markdown]
# # Load Data

# %%
# load baseline data
import pandas as pd
rul_baseline = pd.read_csv('/data/rul_result.csv')
if 'Unnamed: 0' in rul_baseline.columns:
    rul_baseline.drop(['Unnamed: 0'], axis=1, inplace=True)
rul_baseline

# %%
rul_baseline.to_csv('/results/rul_result.csv')
